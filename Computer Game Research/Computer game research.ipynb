# %% [markdown]
# <div  style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
#
# **Андрей, привет!**
#
# Меня зовут Василий Митров и я буду проверять твой проект. Предлагаю общаться на «ты». Если это неприемлемо, то дай мне знать и мы перейдем на «вы».
#
# Для удобства я оставлю комментарии в отдельных ячейках Markdown с заголовком «Комментарий ревьюера». Пожалуйста, не перемещай, не изменяй и не удаляй их - так наше общение будет более продуктивным. Я буду использовать цветовую разметку:
#
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера</b>
#
# ✍ Так выделены самые важные замечания. Без их отработки проект не будет принят. При проверке я обращаю внимание не только на код, но и на интерпретацию и анализ результатов, а также соответствие данных техническому заданию.
# </div>
#
# <div class="alert alert-warning" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера</b>
#
# 📝 Так выделены небольшие замечания или рекомендации. Постарайся, пожалуйста, учесть эти комментарии в этом проекте или в будущих проектах.
# </div>
#
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера</b>
#
# 👍 Так выделены все остальные комментарии, включая рекомендации, позитивные моменты или какие-то рассуждения и пояснения.
# </div>
#
# **Важные дополнения:**
#
# * <u>Идеально, когда проект структурирован. Где названия разделов и подразделов будут записаны в ячейках [Markdown](https://paulradzkov.com/2014/markdown_cheatsheet/?).</u>
#
#
# * <u>Проверь проект на работоспособность перед отправкой на проверку. Сделать это можно так: `Kernel -> Restart And Run All -> Restart And Run All Cells` предварительно сохранив проект нажав на дискету в левом верхнем углу. Это важный навык, который тебе пригодится как на собеседовании, при выполнении тестового задания, так и перед совещанием у руководства компании. Помни, ревьюеры не вносят изменения в код, даже если это путь к датасету или ячейка в неверном формате (code/mardown).</u>
#
# Давай работать над проектом в диалоге: если ты что-то меняешь в проекте или отвечаешь на мои комментарии — пиши об этом. Мне будет легче отследить изменения, если ты выделишь свои комментарии:
#
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
# Например, вот так. Также, если есть какие-то вопросы, или что-то осталось непонятным по ревью - спрашивай в таких блоках и я постараюсь дать ответ.
# </div>
#
# ---

# %% [markdown]
# # Сборный проект №1

# %% [markdown]
# ### Описание проекта <a id='1'></a>

# %% [markdown]
# В моих руках как сотрудника интернет-магазина «Стримчик», продающего по всему миру компьютерные игры, данные о продажах игр, оценках пользователей и экспертов, жанрах и платформах. Данные собраны из открытых источников. Данные до 2016 года.
#
# Задачи:
# - Выявить определяющие успешность игры закономерности, что бы сделать ставку на потенциально популярный продукт и спланировать рекламные компании;
# - Отработать принцип работы с данными, для решения таких задач на будущие годы.

# %% [markdown]
# ### План работ:

# %% [markdown]
# 1. Открыть файл с данными и изучить общую информацию
# 2. Подготовить данные:
# - Проверить названия столбцов. Исправить, если требуется;
# - Проверить типы данных. Исправить, если требуется;
# - Проверить пропуски в данных. Узнать их природу появления и решить оставить, заполнять или удалять;
# - Добавить требуемые колонки с данными для анализа;
#
# 3. Провести исследовательский анализ данных. Сравнить разные показатели по годам и прибыли. Определить какой лучше период брать для прогноза на следующий год;
# 4. Собрать портреты пользователей каждого представленного региона, указав интересы по платформам, жанрам и т.д.;
# 5. Построить и проверить гипотезы;
# 6. Написать вывод

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Вступление в работу очень важно. Так ты поясняешь то, чему она посвящена. Еще лучше будет, если ты сделаешь план работы с гиперссылками. Да, есть плагин ToC. Но хорошо бы уметь реализовывать интерактивный план проекта вручную. Как это реализовать - смотри по ссылке :https://stackoverflow.com/questions/49535664/how-to-hyperlink-in-a-jupyter-notebook/49717704

# %% [markdown]
# ## Общая информация о данных

# %%
import pandas as pd
import numpy as np
from scipy.stats import uniform, norm
from scipy import stats as st
import matplotlib.pyplot as plt
from scipy.stats import binom

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Правильно, что весь импорт ты проводишь в первой ячейке работы. Так твой коллега, запускающий работу, будет в курсе используемых в ней библиотек и сможет при необходимости быстро настроить окружение.
# </div>

# %%
pd.options.mode.chained_assignment = None

# %%
try:
    games = pd.read_csv('https://code.s3.yandex.net/datasets/games.csv')
except:
    games = pd.read_csv('/datasets/games.csv')

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍 Здорово, что следишь за универсальностью загрузки данных и используешь `try-except` блок.
# </div>

# %% [markdown]
# Случайно выбранные 10 строк из датафрейма

# %%
games.sample(10)
# Out:
#                                               Name Platform  Year_of_Release  \
# 5606                    Rayman 2: The Great Escape       PS           2000.0
# 727                                  Borderlands 2      PS3           2012.0
# 892                               Mortal Kombat II     SNES           1993.0
# 16461                              Wand of Fortune      PS2           2009.0
# 12745              Atari's Greatest Hits: Volume 2       DS           2011.0
# 3354   From TV Animation One Piece: Grand Battle 2       PS           2002.0
# 11003                          Monopoly Collection      Wii           2011.0
# 16316                                Family Jockey      Wii           2008.0
# 9244      Daytona USA Championship Circuit Edition      SAT           1995.0
# 3735                                  Petz Nursery       DS           2009.0
#
#             Genre  NA_sales  EU_sales  JP_sales  Other_sales  Critic_Score  \
# ...

# %%
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16713 non-null  object
#  1   Platform         16715 non-null  object
#  2   Year_of_Release  16446 non-null  float64
#  3   Genre            16713 non-null  object
#  4   NA_sales         16715 non-null  float64
#  5   EU_sales         16715 non-null  float64
#  6   JP_sales         16715 non-null  float64
#  7   Other_sales      16715 non-null  float64
#  8   Critic_Score     8137 non-null   float64
#  9   User_Score       10014 non-null  object
#  10  Rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %%
games['Year_of_Release'].describe()
# Out:
# count    16446.000000
# mean      2006.484616
# std          5.877050
# min       1980.000000
# 25%       2003.000000
# 50%       2007.000000
# 75%       2010.000000
# max       2016.000000
# Name: Year_of_Release, dtype: float64

# %% [markdown]
# В таблице следующие данные:
#
# - `Name` - название игры
# - `Platform` - платформа
# - `Year_of_Release` - год выпуска
# - `Genre` - жанр игры
# - `NA_sales` - продажи в Северной Америке (миллионы проданных копий)
# - `EU_sales` - продажи в Европе (миллионы проданных копий)
# - `JP_sales` - продажи в Японии (миллионы проданных копий)
# - `Other_sales` - продажи в других странах (миллионы проданных копий)
# - `Critic_Score` - оценка критиков (максимум 100)
# - `User_Score` - оценка пользователей (максимум 10)
# - `Rating` - рейтинг от организации ESRB (англ. Entertainment Software Rating Board). Эта ассоциация определяет рейтинг компьютерных игр и присваивает им подходящую возрастную категорию.
#
# Данные представлены с 1980 по 2016 год.
#
# Всего 16715 строк.
#
# Видны проблемы:
# - Названия столбцов надо привести к нижнему регистру;
# - Год выпуска с типом данных `float`, надо изменить на `int`;
# - Оценка пользователей с типом данных `object`, надо изменить на `float`;
# - Присутствуют нули в колонках с продажами по регионам;
# - Пропущенные значения в колонках:
# 1. `Name` - 2 значения;
# 2. `Year_of_Release` - 269 значений;
# 3. `Genre` - 2 значения;
# 4. `Critic_Score` - 8578 значений;
# 5. `User_Score` - 6701 значение;
# 6. `Rating` - 6766 значений;

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Хорошая вводная часть.
#
# Рекомендую создать универсальную функцию, которая будет принимать на вход датафрейм, а на выходе она будет выводить всего нужные характеристики, например, head, describe, info, дубликаты и т.п.
# </div>

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# ### Приведение названий столбцов к нижнему регистру.

# %%
games.columns = games.columns.str.lower()

# %%
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16713 non-null  object
#  1   platform         16715 non-null  object
#  2   year_of_release  16446 non-null  float64
#  3   genre            16713 non-null  object
#  4   na_sales         16715 non-null  float64
#  5   eu_sales         16715 non-null  float64
#  6   jp_sales         16715 non-null  float64
#  7   other_sales      16715 non-null  float64
#  8   critic_score     8137 non-null   float64
#  9   user_score       10014 non-null  object
#  10  rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %% [markdown]
# ### Поиск пропущенных значений

# %% [markdown]
# #### Колонка с годом выпуска

# %%
games[games['year_of_release'].isna()]
# Out:
#                                     name platform  year_of_release  \
# 183                      Madden NFL 2004      PS2              NaN
# 377                     FIFA Soccer 2004      PS2              NaN
# 456           LEGO Batman: The Videogame      Wii              NaN
# 475           wwe Smackdown vs. Raw 2006      PS2              NaN
# 609                       Space Invaders     2600              NaN
# ...                                  ...      ...              ...
# 16373  PDC World Championship Darts 2008      PSP              NaN
# 16405                      Freaky Flyers       GC              NaN
# 16448                          Inversion       PC              NaN
# 16458        Hakuouki: Shinsengumi Kitan      PS3              NaN
# 16522                       Virtua Quest       GC              NaN
#
#               genre  na_sales  eu_sales  jp_sales  other_sales  critic_score  \
# 183          Sports      4.26      0.26      0.01         0.71          94.0
# ...

# %% [markdown]
# 269 строк с пропусками. В названиях некоторых игр есть числа и это годы выпуска. Сколько таких игр?

# %%
(games[games['year_of_release'].isna()]
 [games[games['year_of_release'].isna()]
 ['name'].astype('str').str.contains('20', '19')]
)
# Out:
#                                     name platform  year_of_release     genre  \
# 183                      Madden NFL 2004      PS2              NaN    Sports
# 377                     FIFA Soccer 2004      PS2              NaN    Sports
# 475           wwe Smackdown vs. Raw 2006      PS2              NaN  Fighting
# 1650                 NASCAR Thunder 2003      PS2              NaN    Racing
# 2492                  MLB SlugFest 20-03      PS2              NaN    Sports
# 2572      PES 2009: Pro Evolution Soccer      PSP              NaN    Sports
# 3486                     Madden NFL 2002       XB              NaN    Sports
# 4775                    NFL GameDay 2003      PS2              NaN    Sports
# 5156                       NBA Live 2003       XB              NaN    Sports
# 5336                  Tomb Raider (2013)       PC              NaN    Action
# 5655              All-Star Baseball 2005      PS2              NaN    Sports
# ...

# %%
(games[games['year_of_release'].isna()]
 [games[games['year_of_release'].isna()]
 ['name'].astype('str').str.contains('20', '19')]
 ['name'].count()
)
# Out:
# 19

# %% [markdown]
# 19 игр, в 2-ух из которых цифры не говорят о годе выпуска. Заполним значение года цифрами из названия.

# %%
years = [2002, 2003, 2004, 2005, 2006,2007, 2008, 2009, 2011, 2013]
nan_years = games[games['year_of_release'].isna()]
for year in years:

    for i in range(len(years)):
        try:
            ind = (nan_years[nan_years['name'].
                  astype('str').str.contains(str(year))].index.values[i]
            )
            games.loc[ind, 'year_of_release'] = year
        except:
            continue

# %%
(games[games['year_of_release'].isna()]
 [games[games['year_of_release'].isna()]
 ['name'].astype('str').str.contains('20', '19')]
)
# Out:
#                     name platform  year_of_release   genre  na_sales  \
# 2492  MLB SlugFest 20-03      PS2              NaN  Sports      0.41
# 6954             Jet X20      PS2              NaN  Racing      0.11
#
#       eu_sales  jp_sales  other_sales  critic_score user_score rating
# 2492      0.32       0.0         0.11          77.0        8.2      E
# 6954      0.09       0.0         0.03           NaN        NaN    NaN

# %% [markdown]
# Заполним годы выпуска, взяв значения из этих же игр, только с других платформ.

# %%
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16713 non-null  object
#  1   platform         16715 non-null  object
#  2   year_of_release  16463 non-null  float64
#  3   genre            16713 non-null  object
#  4   na_sales         16715 non-null  float64
#  5   eu_sales         16715 non-null  float64
#  6   jp_sales         16715 non-null  float64
#  7   other_sales      16715 non-null  float64
#  8   critic_score     8137 non-null   float64
#  9   user_score       10014 non-null  object
#  10  rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %%
for i in range(len(games)):
    if np.isnan(games.loc[i, 'year_of_release']) == True:
        game_name = games.loc[i, 'name']
        if games.query('year_of_release.notna() & name == @game_name')['name'].count() > 0:
            game_year = (games.query('year_of_release.notna() & name == @game_name')
                         ['year_of_release'].reset_index().loc[0, 'year_of_release']
                        )
            games.loc[i, 'year_of_release'] = game_year
        else:
            continue
    else:
        continue

# %%
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16713 non-null  object
#  1   platform         16715 non-null  object
#  2   year_of_release  16576 non-null  float64
#  3   genre            16713 non-null  object
#  4   na_sales         16715 non-null  float64
#  5   eu_sales         16715 non-null  float64
#  6   jp_sales         16715 non-null  float64
#  7   other_sales      16715 non-null  float64
#  8   critic_score     8137 non-null   float64
#  9   user_score       10014 non-null  object
#  10  rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %% [markdown]
# Заполнили еще 113 значений в колонке с годом выпуска.

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 📝
# Доля пропусков здесь менее 5% и мы вполне можем их удалить.
# </div>

# %% [markdown]
# #### Поиск пропущенных значений в столбце названия игры.

# %%
games[games['name'].isna()]
# Out:
#       name platform  year_of_release genre  na_sales  eu_sales  jp_sales  \
# 659    NaN      GEN           1993.0   NaN      1.78      0.53      0.00
# 14244  NaN      GEN           1993.0   NaN      0.00      0.00      0.03
#
#        other_sales  critic_score user_score rating
# 659           0.08           NaN        NaN    NaN
# 14244         0.00           NaN        NaN    NaN

# %% [markdown]
# Две игры и из данных только платформа, год выпуска - 1993 и данные о продажах. Удаляем.

# %%
games = games.dropna(subset=['name'])

# %%
games = games.reset_index(drop=True)

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Согласен
# </div>

# %% [markdown]
# #### Пропуски в колонках с рейтингом

# %%
games[games['critic_score'].isna()].sample(30)
# Out:
#                                                     name platform  \
# 15761                                Gadget Racers (PAL)      PS2
# 7547                     Rocket Power: Zero Gravity Zone      GBA
# 9821                                    NFL QB Club 2001      N64
# 9309      Avatar: The Last Airbender - The Burning Earth     X360
# 7141                       Hatsune Miku: Project Mirai 2      3DS
# 7139                          101-in-1 Party Megamix Wii      Wii
# 12307                                      Cosmos Chaos!       DS
# 3549                                   Tales of Zestiria      PS3
# 10687                                           NBA 2K16       PC
# 9888                      Uta no * Prince-Sama: All Star      PSP
# 6704             Tennis no Oji-Sama: Genius Boys Academy      GBA
# 10382                                     Space Invaders      GBA
# 3311                              Tomb Raider Chronicles       PS
# ...

# %%
games['critic_score'].unique()
# Out:
# array([76., nan, 82., 80., 89., 58., 87., 91., 61., 97., 95., 77., 88.,
#        83., 94., 93., 85., 86., 98., 96., 90., 84., 73., 74., 78., 92.,
#        71., 72., 68., 62., 49., 67., 81., 66., 56., 79., 70., 59., 64.,
#        75., 60., 63., 69., 50., 25., 42., 44., 55., 48., 57., 29., 47.,
#        65., 54., 20., 53., 37., 38., 33., 52., 30., 32., 43., 45., 51.,
#        40., 46., 39., 34., 35., 41., 36., 28., 31., 27., 26., 19., 23.,
#        24., 21., 17., 22., 13.])

# %%
games['user_score'].unique()
# Out:
# array(['8', nan, '8.3', '8.5', '6.6', '8.4', '8.6', '7.7', '6.3', '7.4',
#        '8.2', '9', '7.9', '8.1', '8.7', '7.1', '3.4', '5.3', '4.8', '3.2',
#        '8.9', '6.4', '7.8', '7.5', '2.6', '7.2', '9.2', '7', '7.3', '4.3',
#        '7.6', '5.7', '5', '9.1', '6.5', 'tbd', '8.8', '6.9', '9.4', '6.8',
#        '6.1', '6.7', '5.4', '4', '4.9', '4.5', '9.3', '6.2', '4.2', '6',
#        '3.7', '4.1', '5.8', '5.6', '5.5', '4.4', '4.6', '5.9', '3.9',
#        '3.1', '2.9', '5.2', '3.3', '4.7', '5.1', '3.5', '2.5', '1.9', '3',
#        '2.7', '2.2', '2', '9.5', '2.1', '3.6', '2.8', '1.8', '3.8', '0',
#        '1.6', '9.6', '2.4', '1.7', '1.1', '0.3', '1.5', '0.7', '1.2',
#        '2.3', '0.5', '1.3', '0.2', '0.6', '1.4', '0.9', '1', '9.7'],
#       dtype=object)

# %%
games['rating'].unique()
# Out:
# array(['E', nan, 'M', 'T', 'E10+', 'K-A', 'AO', 'EC', 'RP'], dtype=object)

# %% [markdown]
# В колонке `user_score` есть значение `tbd` - что означает *To Be Determined* - предстоит определить.
# 1. Это мешает перевести тип данных этой колонки в численный
# 2. По сути это тоже отсутствие оценки. Можно заменить на NaN.

# %%
games.loc[:, 'user_score'].loc[games['user_score'] == 'tbd'] = np.nan
# Out:
# /var/folders/x5/shnp329907331sz0s0n6_20m0000gn/T/ipykernel_23143/2125521484.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   games.loc[:, 'user_score'].loc[games['user_score'] == 'tbd'] = np.nan

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍 Верно, `tbd` означает `To Be Determined`, т.к. игра ещё не выпущена. Тут можно заменить заглушкой, а можно привести в nan
# </div>

# %%
games['user_score'].unique()
# Out:
# array(['8', nan, '8.3', '8.5', '6.6', '8.4', '8.6', '7.7', '6.3', '7.4',
#        '8.2', '9', '7.9', '8.1', '8.7', '7.1', '3.4', '5.3', '4.8', '3.2',
#        '8.9', '6.4', '7.8', '7.5', '2.6', '7.2', '9.2', '7', '7.3', '4.3',
#        '7.6', '5.7', '5', '9.1', '6.5', '8.8', '6.9', '9.4', '6.8', '6.1',
#        '6.7', '5.4', '4', '4.9', '4.5', '9.3', '6.2', '4.2', '6', '3.7',
#        '4.1', '5.8', '5.6', '5.5', '4.4', '4.6', '5.9', '3.9', '3.1',
#        '2.9', '5.2', '3.3', '4.7', '5.1', '3.5', '2.5', '1.9', '3', '2.7',
#        '2.2', '2', '9.5', '2.1', '3.6', '2.8', '1.8', '3.8', '0', '1.6',
#        '9.6', '2.4', '1.7', '1.1', '0.3', '1.5', '0.7', '1.2', '2.3',
#        '0.5', '1.3', '0.2', '0.6', '1.4', '0.9', '1', '9.7'], dtype=object)

# %%
games['user_score'] = games['user_score'].astype('float')

# %%
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16713 entries, 0 to 16712
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16713 non-null  object
#  1   platform         16713 non-null  object
#  2   year_of_release  16574 non-null  float64
#  3   genre            16713 non-null  object
#  4   na_sales         16713 non-null  float64
#  5   eu_sales         16713 non-null  float64
#  6   jp_sales         16713 non-null  float64
#  7   other_sales      16713 non-null  float64
#  8   critic_score     8137 non-null   float64
#  9   user_score       7590 non-null   float64
#  10  rating           9949 non-null   object
# dtypes: float64(7), object(4)
# memory usage: 1.4+ MB

# %% [markdown]
# Пропуски значений рейтинга можно заполнить только в колонке `rating`, так как значения можно взять от этих же игр с других платформ. В колонках с рейтингом пользователей и критиков оценки на разных платформах отличаются.

# %%
games[games.duplicated(subset='name')].sort_values('name')
# Out:
#                                name platform  year_of_release     genre  \
# 3861           Frozen: Olaf's Quest       DS           2013.0  Platform
# 9506         007: Quantum of Solace       DS           2008.0    Action
# 4474         007: Quantum of Solace      PS2           2008.0    Action
# 1784         007: Quantum of Solace      PS3           2008.0    Action
# 3119         007: Quantum of Solace      Wii           2008.0    Action
# ...                             ...      ...              ...       ...
# 12647     pro evolution soccer 2011       PC           2010.0    Sports
# 3303      pro evolution soccer 2011     X360           2010.0    Sports
# 4663      pro evolution soccer 2011      PS2           2010.0    Sports
# 2582      pro evolution soccer 2011      PSP           2010.0    Sports
# 15610  uDraw Studio: Instant Artist     X360           2011.0      Misc
#
#        na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# ...

# %%
for i in range(len(games)):
    if type(games.loc[i, 'rating']) == float:
        game_name = games.loc[i, 'name']
        if games.query('rating.notna() & name == @game_name')['name'].count() > 0:
            game_rating = games.query('rating.notna() & name == @game_name')['rating'].reset_index().loc[0, 'rating']
            games.loc[i, 'rating'] = game_rating
        else:
            continue
    else:
        continue

# %%
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16713 entries, 0 to 16712
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16713 non-null  object
#  1   platform         16713 non-null  object
#  2   year_of_release  16574 non-null  float64
#  3   genre            16713 non-null  object
#  4   na_sales         16713 non-null  float64
#  5   eu_sales         16713 non-null  float64
#  6   jp_sales         16713 non-null  float64
#  7   other_sales      16713 non-null  float64
#  8   critic_score     8137 non-null   float64
#  9   user_score       7590 non-null   float64
#  10  rating           10386 non-null  object
# dtypes: float64(7), object(4)
# memory usage: 1.4+ MB

# %% [markdown]
# Стало 10386, было 9949. Заполнили 437 пропущенных значения.

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 📝
# Что касается рейтинга ESRB,  пропуски в этой колонке не являются просто ошибкой заполнения данных, а несут определенную информацию. Что бы проанализировать ее, на пропуски следует поставить заглушку.
# </div>

# %%
games['rating'] = games['rating'].fillna('unknown')

# %%
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16713 entries, 0 to 16712
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16713 non-null  object
#  1   platform         16713 non-null  object
#  2   year_of_release  16574 non-null  float64
#  3   genre            16713 non-null  object
#  4   na_sales         16713 non-null  float64
#  5   eu_sales         16713 non-null  float64
#  6   jp_sales         16713 non-null  float64
#  7   other_sales      16713 non-null  float64
#  8   critic_score     8137 non-null   float64
#  9   user_score       7590 non-null   float64
#  10  rating           16713 non-null  object
# dtypes: float64(7), object(4)
# memory usage: 1.4+ MB

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента v.1</b>
#
# Сделал заглушки для пропущенных рейтингов ESRB, дальше сделаю новые выводы.
# Я об этом не подумал. Спасибо!
# </div>

# %% [markdown]
# Учитывая, что данные взяты из открытых источников, пропуски в значениях с рейтингом могли появиться по разным причинам. Например Игра не популярна и очень мало оценок собрала, а рейтинг для полной объективности формируется только от определенного числа оценок. Сложности со сбором, группировкой и переносом данных. Тут тоже возможны потери. В колонке с рейтингом ESRB могуть быть такие же истории + они в целом не все игры оценили или собираются оценивать, так как это коммерческая организация и они сами определяют свой интерес.
#
# Пропуски с годом выпуска могут быть обусловлены технической частью, тоесть потерей данных при сборе, группировке и переносе данных. Потому что данные о годе выпуска игры передаются производителем.

# %% [markdown]
# ### Суммарные продажи по всем регионам

# %% [markdown]
# Добавим отдельный столбец с продажами по всем регионам (миллионы проданных копий).

# %%
games['total_sales'] = games['na_sales'] + games['eu_sales'] + games['jp_sales'] + games['other_sales']

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Отлично! Колонка с общими продажами создана.
#
# Также, мы можем работать с набором столбцов:</font><br>
# `data = data[['na_sales','eu_sales','jp_sales', 'other_sales']].sum(axis = 1)`
# </div>

# %%
games.sample(10)
# Out:
#                                               name platform  year_of_release  \
# 8489                             Kya: Dark Lineage      PS2           2003.0
# 1004                        Star Wars: Battlefront       XB           2004.0
# 2842                           Jampack Winter 2001      PS2           2001.0
# 11131  World Soccer Winning Eleven 8 International       XB           2004.0
# 7327                                   Doom (2016)       PC           2016.0
# 7750                                       Manhunt       XB           2004.0
# 10866              Fresh PreCure! Asobi Collection       DS           2009.0
# 14082                           RLH: Run Like Hell       XB           2003.0
# 2638                                Rayman Origins     X360           2011.0
# 8432               Naval Assault: The Killing Tide     X360           2010.0
#
#             genre  na_sales  eu_sales  jp_sales  other_sales  critic_score  \
# ...

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# ✍
# Замечания:
#
# * Отсутствует проверка явных дубликатов, а это основа предобработки данных.
#
# * Мы также должны учесть возможность наличия неявных дубликатов, которые могут возникнуть, если данные были собраны из разных источников или при возникновении технических ошибок. Учитывая, что мы уже привели названия столбцов к нижнему регистру, предлагаю провести проверку на дубликаты, основываясь на столбцах `'name', 'platform' и 'year_of_release'.`
#
# Пожалуйста, выполни эту проверку и определи наличие неявных дубликатов, а также необходимо принять решение, как с ними поступить.
#
# * Отсутствует промежуточный вывод о проделанной работе в разделе.
#
# Дополни, пожалуйста.
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента v.1</b>
#
# Ниже сделал проверку на явные и неявные дубликаты. Провел обработку того, что нашел. В конце написал вывод.
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍
# Отлично!
# </div>

# %% [markdown]
# Проверим датафрейм на дубликаты.

# %%
games[games.duplicated()]
# Out:
# Empty DataFrame
# Columns: [name, platform, year_of_release, genre, na_sales, eu_sales, jp_sales, other_sales, critic_score, user_score, rating, total_sales]
# Index: []

# %% [markdown]
# Дубликатов нет.

# %% [markdown]
# Сравним количество уникальных значений в колонке названия игр с разными регистрами и с нижним регистром.

# %%
games['name'].value_counts()
# Out:
# name
# Need for Speed: Most Wanted                         12
# Ratatouille                                          9
# LEGO Marvel Super Heroes                             9
# FIFA 14                                              9
# Madden NFL 07                                        9
#                                                     ..
# Jewels of the Tropical Lost Island                   1
# Sherlock Holmes and the Mystery of Osborne House     1
# The King of Fighters '95 (CD)                        1
# Megamind: Mega Team Unite                            1
# Haitaka no Psychedelica                              1
# Name: count, Length: 11559, dtype: int64

# %%
games['name'] = games['name'].str.lower()

# %%
games['name'].value_counts()
# Out:
# name
# need for speed: most wanted                         12
# ratatouille                                          9
# lego marvel super heroes                             9
# fifa 14                                              9
# madden nfl 07                                        9
#                                                     ..
# jewels of the tropical lost island                   1
# sherlock holmes and the mystery of osborne house     1
# the king of fighters '95 (cd)                        1
# megamind: mega team unite                            1
# haitaka no psychedelica                              1
# Name: count, Length: 11559, dtype: int64

# %% [markdown]
# Количество одинаковое, значит таких неявных дубликатов нет.

# %% [markdown]
# Проверим дубликаты по совпадающим колонкам `name`, `platform`, `year_of_release`.

# %%
games[games.duplicated(['name', 'platform', 'year_of_release'])]
# Out:
#                 name platform  year_of_release   genre  na_sales  eu_sales  \
# 16228  madden nfl 13      PS3           2012.0  Sports       0.0      0.01
#
#        jp_sales  other_sales  critic_score  user_score rating  total_sales
# 16228       0.0          0.0          83.0         5.5      E         0.01

# %%
games.query('name == "madden nfl 13"')
# Out:
#                 name platform  year_of_release   genre  na_sales  eu_sales  \
# 507    madden nfl 13     X360           2012.0  Sports      2.53      0.15
# 604    madden nfl 13      PS3           2012.0  Sports      2.11      0.22
# 3985   madden nfl 13      Wii           2012.0  Sports      0.47      0.00
# 5886   madden nfl 13      PSV           2012.0  Sports      0.28      0.00
# 7065   madden nfl 13     WiiU           2012.0  Sports      0.21      0.00
# 16228  madden nfl 13      PS3           2012.0  Sports      0.00      0.01
#
#        jp_sales  other_sales  critic_score  user_score rating  total_sales
# 507         0.0         0.17          81.0         5.8      E         2.85
# 604         0.0         0.23          83.0         5.5      E         2.56
# 3985        0.0         0.03           NaN         7.3      E         0.50
# 5886        0.0         0.02          63.0         7.3      E         0.30
# ...

# %%
games = games.drop(16228)

# %% [markdown]
# Нашли и удалили один дубликат.

# %% [markdown]
# Попробуем найти дубликаты по названию игры и названию платформы.

# %%
games[games.duplicated(['name', 'platform'])]
# Out:
#                               name platform  year_of_release     genre  \
# 1590   need for speed: most wanted     X360           2005.0    Racing
# 4126            sonic the hedgehog      PS3           1991.0  Platform
# 11714  need for speed: most wanted       PC           2012.0    Racing
#
#        na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# 1590        1.0      0.13      0.02         0.10          83.0         8.5
# 4126        0.0      0.48      0.00         0.00          43.0         4.1
# 11714       0.0      0.06      0.00         0.02          82.0         8.5
#
#       rating  total_sales
# 1590       T         1.25
# 4126    E10+         0.48
# 11714      T         0.08

# %%
games.query('name == "need for speed: most wanted"')
# Out:
#                               name platform  year_of_release   genre  \
# 253    need for speed: most wanted      PS2           2005.0  Racing
# 523    need for speed: most wanted      PS3           2012.0  Racing
# 1189   need for speed: most wanted     X360           2012.0  Racing
# 1590   need for speed: most wanted     X360           2005.0  Racing
# 1997   need for speed: most wanted       XB           2005.0  Racing
# 2047   need for speed: most wanted      PSV           2012.0  Racing
# 3580   need for speed: most wanted       GC           2005.0  Racing
# 5971   need for speed: most wanted       PC           2005.0  Racing
# 6272   need for speed: most wanted     WiiU           2013.0  Racing
# 6409   need for speed: most wanted       DS           2005.0  Racing
# 6472   need for speed: most wanted      GBA           2005.0  Racing
# 11714  need for speed: most wanted       PC           2012.0  Racing
#
# ...

# %% [markdown]
# Здесь есть дубликаты, но отличается год выпуска. Но проверив в интернете, оказалось, что и правда есть такая игра 2005 и 2012 года выпуска

# %% [markdown]
# Проверим `sonic the hedgehog`

# %%
games.query('name == "sonic the hedgehog"')
# Out:
#                     name platform  year_of_release     genre  na_sales  \
# 257   sonic the hedgehog      GEN           1991.0  Platform      3.03
# 1744  sonic the hedgehog      PS3           2006.0  Platform      0.41
# 1995  sonic the hedgehog     X360           2006.0  Platform      0.44
# 4126  sonic the hedgehog      PS3           1991.0  Platform      0.00
#
#       eu_sales  jp_sales  other_sales  critic_score  user_score rating  \
# 257       0.91      0.26         0.13           NaN         NaN   E10+
# 1744      0.06      0.04         0.66          43.0         4.1   E10+
# 1995      0.48      0.00         0.11          46.0         4.4   E10+
# 4126      0.48      0.00         0.00          43.0         4.1   E10+
#
#       total_sales
# 257          4.33
# 1744         1.17
# 1995         1.03
# 4126         0.48

# %% [markdown]
# Тут очевидно произошла ошибка при сборе или переносе данных. В 1991 году не было платформы `PS3`. При этом у этой игры есть оценки критиков и пользователей, в то время как у этой же игры на платформе `GEN` такого нет. Посмотрим были ли оценки у игрв в 1991 году и ранее.

# %%
games.query('year_of_release < 1992 & critic_score.notna() & user_score.notna()')
# Out:
#                      name platform  year_of_release       genre  na_sales  \
# 4126   sonic the hedgehog      PS3           1991.0    Platform       0.0
# 14468           alter ego       PC           1985.0  Simulation       0.0
# 14619             simcity       PC           1988.0  Simulation       0.0
#
#        eu_sales  jp_sales  other_sales  critic_score  user_score rating  \
# 4126       0.48       0.0         0.00          43.0         4.1   E10+
# 14468      0.03       0.0         0.01          59.0         5.8      T
# 14619      0.02       0.0         0.01          64.0         2.2   E10+
#
#        total_sales
# 4126          0.48
# 14468         0.04
# 14619         0.03

# %% [markdown]
# Только на плтаформе `PC` и то на двух играх. Стоит удалить этого соника.

# %%
games = games.drop(4126)

# %% [markdown]
# Названия колонок привели к нижнему регистру, у 130 игр заполнили пропущенные значения в колонке года выпуска, удалили 2 игры без навания, заполнили 437 пропущенных значений в колонке с рейтингом ESRB, нашли неявные дубликаты и удалили их.

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Сколько игр выпускалось в разные годы?

# %%
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16711 entries, 0 to 16712
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16711 non-null  object
#  1   platform         16711 non-null  object
#  2   year_of_release  16572 non-null  float64
#  3   genre            16711 non-null  object
#  4   na_sales         16711 non-null  float64
#  5   eu_sales         16711 non-null  float64
#  6   jp_sales         16711 non-null  float64
#  7   other_sales      16711 non-null  float64
#  8   critic_score     8135 non-null   float64
#  9   user_score       7588 non-null   float64
#  10  rating           16711 non-null  object
#  11  total_sales      16711 non-null  float64
# dtypes: float64(8), object(4)
# memory usage: 1.7+ MB

# %%
games.drop_duplicates('name').groupby('year_of_release')['name'].count()
# Out:
# year_of_release
# 1980.0      8
# 1981.0     43
# 1982.0     33
# 1983.0     16
# 1984.0     13
# 1985.0     13
# 1986.0     21
# 1987.0     15
# 1988.0     11
# 1989.0     14
# 1990.0     14
# 1991.0     40
# 1992.0     37
# 1993.0     58
# 1994.0    112
# 1995.0    200
# 1996.0    247
# 1997.0    268
# 1998.0    347
# 1999.0    293
# 2000.0    300
# 2001.0    410
# 2002.0    572
# 2003.0    491
# 2004.0    523
# 2005.0    618
# 2006.0    731
# 2007.0    839
# 2008.0    987
# 2009.0    957
# 2010.0    862
# 2011.0    751
# 2012.0    406
# 2013.0    293
# 2014.0    279
# 2015.0    331
# 2016.0    279
# Name: name, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(13, 6))

ax.hist(games.drop_duplicates('name')['year_of_release'], bins=37, linewidth=0.5, edgecolor="white")
ax.grid()

ax.set_title('Количество выпущенных игр по годам')
ax.set_xlabel('Год выпуска игр')
ax.set_ylabel('Количество выпущенных игр')
plt.show()

# %% [markdown]
# На графике видна тенденция подъема и спада количества выпускаемых игр выпускаемых в год. Видны два шага спада в 2008 и 2012 годах. В 2015 году был небольшой подъем и в 2016 тот же показатель, что и в 2014. Как бы там в прошлом не было, сейчас стоит опираться на данные последних 4 лет, так как они, судя по графику приближены к текущей ситуации.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Не могу не отметить отличную визуализацию. Здорово, что оформляешь графики правильно.
# </div>

# %% [markdown]
# ### Как менялись продажи по платформам?

# %%
pd.set_option('display.max_columns', None)
games.pivot_table(index='year_of_release', columns='platform', values='total_sales', aggfunc='sum')
# Out:
# platform          2600   3DO    3DS    DC      DS     GB    GBA     GC    GEN  \
# year_of_release
# 1980.0           11.38   NaN    NaN   NaN     NaN    NaN    NaN    NaN    NaN
# 1981.0           35.68   NaN    NaN   NaN     NaN    NaN    NaN    NaN    NaN
# 1982.0           28.88   NaN    NaN   NaN     NaN    NaN    NaN    NaN    NaN
# 1983.0            5.84   NaN    NaN   NaN     NaN    NaN    NaN    NaN    NaN
# 1984.0            0.27   NaN    NaN   NaN     NaN    NaN    NaN    NaN    NaN
# 1985.0            0.45   NaN    NaN   NaN    0.02    NaN    NaN    NaN    NaN
# 1986.0            0.67   NaN    NaN   NaN     NaN    NaN    NaN    NaN    NaN
# 1987.0            1.94   NaN    NaN   NaN     NaN    NaN    NaN    NaN    NaN
# 1988.0            0.74   NaN    NaN   NaN     NaN   1.43    NaN    NaN    NaN
# 1989.0            0.63   NaN    NaN   NaN     NaN  64.97    NaN    NaN    NaN
# 1990.0             NaN   NaN    NaN   NaN     NaN   4.89    NaN    NaN   2.60
# ...

# %%
games.pivot_table(index='year_of_release', columns='platform', values='total_sales', aggfunc='sum').count().sort_values()
# Out:
# platform
# GG       1
# PCFX     1
# TG16     1
# 3DO      2
# SCD      2
# WS       3
# NG       4
# PS4      4
# XOne     4
# WiiU     5
# GEN      5
# SAT      6
# PSV      6
# GC       7
# DC       7
# N64      8
# GBA      8
# 3DS      8
# XB       9
# SNES    10
# PS      10
# Wii     11
# DS      11
# 2600    11
# PS3     12
# NES     12
# X360    12
# PSP     12
# PS2     13
# GB      13
# PC      26
# dtype: int64

# %%
games.pivot_table(index='year_of_release', columns='platform', values='total_sales', aggfunc='sum').count().sort_values().describe()
# Out:
# count    31.000000
# mean      7.870968
# std       5.142904
# min       1.000000
# 25%       4.000000
# 50%       8.000000
# 75%      11.000000
# max      26.000000
# dtype: float64

# %% [markdown]
# Изучив данные можно сказать, что в среднем новые платформы появляются раз в 8 лет. Сейчас актуальны `DS3`, `PS4`, `XOne`.

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# ✍
# А каков жизненный цикл платформ?
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента v.1</b>
#
# Ниже начну сначала и дополню комментариями
# </div>

# %% [markdown]
# Составим большую таблицу, где будут указаны итоговые продажи разделенные по годам и платформам. Зная в какие годы на какой платформе были или не были продажи, мы сможем сказать в какие годы платформы были актуальны.

# %%
pd.set_option('display.max_columns', None)
games.pivot_table(index='year_of_release', columns='platform', values='total_sales', aggfunc='sum')
# Out:
# platform          2600   3DO    3DS    DC      DS     GB    GBA     GC    GEN  \
# year_of_release
# 1980.0           11.38   NaN    NaN   NaN     NaN    NaN    NaN    NaN    NaN
# 1981.0           35.68   NaN    NaN   NaN     NaN    NaN    NaN    NaN    NaN
# 1982.0           28.88   NaN    NaN   NaN     NaN    NaN    NaN    NaN    NaN
# 1983.0            5.84   NaN    NaN   NaN     NaN    NaN    NaN    NaN    NaN
# 1984.0            0.27   NaN    NaN   NaN     NaN    NaN    NaN    NaN    NaN
# 1985.0            0.45   NaN    NaN   NaN    0.02    NaN    NaN    NaN    NaN
# 1986.0            0.67   NaN    NaN   NaN     NaN    NaN    NaN    NaN    NaN
# 1987.0            1.94   NaN    NaN   NaN     NaN    NaN    NaN    NaN    NaN
# 1988.0            0.74   NaN    NaN   NaN     NaN   1.43    NaN    NaN    NaN
# 1989.0            0.63   NaN    NaN   NaN     NaN  64.97    NaN    NaN    NaN
# 1990.0             NaN   NaN    NaN   NaN     NaN   4.89    NaN    NaN   2.60
# ...

# %% [markdown]
# Таблица хоть и информативная, но не дает создать общее представление из за своего объема. Упростим до названия платформы и количества лет с продажами.

# %%
games.pivot_table(index='year_of_release', columns='platform', values='total_sales', aggfunc='sum').count().sort_values()
# Out:
# platform
# GG       1
# PCFX     1
# TG16     1
# 3DO      2
# SCD      2
# WS       3
# NG       4
# PS4      4
# XOne     4
# WiiU     5
# GEN      5
# SAT      6
# PSV      6
# GC       7
# DC       7
# N64      8
# GBA      8
# 3DS      8
# XB       9
# SNES    10
# PS      10
# Wii     11
# DS      11
# 2600    11
# PS3     12
# NES     12
# X360    12
# PSP     12
# PS2     13
# GB      13
# PC      26
# dtype: int64

# %% [markdown]
# Стало еще понятнее. Тут явно видно, что платформа `PC` очень универсальна и 26 лет как пользуется спросом. Это значение явно выбивается из общего списка. Хотя и список довольно разнородный. Возьмем метод `describe()` что бы посмотреть на данные.

# %%
games.pivot_table(index='year_of_release', columns='platform', values='total_sales', aggfunc='sum').count().sort_values().describe()
# Out:
# count    31.000000
# mean      7.870968
# std       5.142904
# min       1.000000
# 25%       4.000000
# 50%       8.000000
# 75%      11.000000
# max      26.000000
# dtype: float64

# %% [markdown]
# Первый квартиль находится на отметке 4 года, второй(медиана) на отметке 8 лет и третий квартиль на отметке 11 лет. Все занчения ниже 4 и выше 11 лет являются выбросами и не являются показательными. Отметка медианы может говорить о том, что в среднем продажи по платформам идут в течении 8 лет. А это значит, что с момента начала продаж(начала жизни платформы) и до завершения продаж(конца жизни платформы) проходит в среднем 8 лет. Получается, что средний жизненный цикл платформ - 8 лет. Посмотрим на свежие платформы, сделаем выборку той же таблицы но за последние 8 лет.

# %%
pd.set_option('display.max_columns', None)
games.pivot_table(index='year_of_release', columns='platform', values='total_sales', aggfunc='sum').query('year_of_release > 2008')
# Out:
# platform         2600  3DO    3DS  DC      DS  GB  GBA  GC  GEN  GG  N64  NES  \
# year_of_release
# 2009.0            NaN  NaN    NaN NaN  119.56 NaN  NaN NaN  NaN NaN  NaN  NaN
# 2010.0            NaN  NaN   0.30 NaN   85.35 NaN  NaN NaN  NaN NaN  NaN  NaN
# 2011.0            NaN  NaN  63.20 NaN   26.33 NaN  NaN NaN  NaN NaN  NaN  NaN
# 2012.0            NaN  NaN  51.76 NaN   11.67 NaN  NaN NaN  NaN NaN  NaN  NaN
# 2013.0            NaN  NaN  56.57 NaN    1.54 NaN  NaN NaN  NaN NaN  NaN  NaN
# 2014.0            NaN  NaN  43.76 NaN     NaN NaN  NaN NaN  NaN NaN  NaN  NaN
# 2015.0            NaN  NaN  27.78 NaN     NaN NaN  NaN NaN  NaN NaN  NaN  NaN
# 2016.0            NaN  NaN  15.14 NaN     NaN NaN  NaN NaN  NaN NaN  NaN  NaN
#
# platform         NG     PC  PCFX  PS    PS2     PS3     PS4    PSP    PSV  \
# year_of_release
# 2009.0          NaN  17.05   NaN NaN  26.40  130.93     NaN  38.58    NaN
# 2010.0          NaN  26.15   NaN NaN   5.64  142.96     NaN  35.04    NaN
# ...

# %% [markdown]
# `XOne` и `PS4` вышли всего 4 года назад и продажи у них сейчас выше остальных, что значит, что они скорее всего в середине своего жиненного цикла. `WiiU` - уже 5 лет, а `PSV` - 6 лет и продажи у них даже год назад и два не были такими как у `XOne` и `PS4`.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍
#
# </div>

# %% [markdown]
# ### Актуализация данных

# %% [markdown]
# Что бы дальше построить прогноз, нужно взять актуальный период. Учитывая что после 2012 произошел большой спад продаж, то нужно брать данные с 2013 года. Так же зная, что платформы обновляются раз в 8 лет, можно думать, что за 4 последних года информация о платформах будет актуальной.

# %%
games_after_13 = games.query('year_of_release == (2013, 2014, 2015, 2016)')

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Верно. Для целей прогнозирования продаж на следующий год даже в традиционных бизнесах редко берут данные более чем за 2-3 года. А в такой динамично меняющейся индустрии, как компьютерные игры и вовсе не стоит брать слишком большой временной интервал - иначе обязательно захватим уже отжившие тренды. Но и очень короткий период не подходит для прогнозирования, так что надо выбирать золотую середину (но не менее 2-х полных лет и не более 5 лет).
# </div>

# %% [markdown]
# Изучим подробнее данные по платформам. Выберем актуальные платформы.

# %% [markdown]
# Глобальные продажи по платформам.

# %%
games_after_13.groupby('platform')['total_sales'].sum().sort_values()
# Out:
# platform
# DS        1.54
# PSP       3.74
# Wii      13.66
# PSV      32.99
# PC       40.06
# WiiU     64.63
# X360    136.80
# 3DS     143.25
# XOne    159.32
# PS3     181.43
# PS4     314.14
# Name: total_sales, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(13, 6))

ax.bar(games_after_13.groupby('platform')['total_sales'].sum().sort_values().index,
       games_after_13.groupby('platform')['total_sales'].sum().sort_values())

ax.set_title('Продажи  игр по платформам (миллионы копий)', size = 15)
ax.set_ylabel('Миллионы проданных копий')
ax.set_xlabel('Платформа')
ax.grid()
plt.show()

# %% [markdown]
# Глобальные продажи игр в разбивке на платформы по годам.

# %%
pd.set_option('display.max_columns', None)
games_after_13.pivot_table(index='year_of_release', columns='platform', values='total_sales', aggfunc='sum')
# Out:
# platform           3DS    DS     PC     PS3     PS4   PSP    PSV   Wii   WiiU  \
# year_of_release
# 2013.0           56.57  1.54  13.01  113.25   25.99  3.38  10.59  8.59  21.65
# 2014.0           43.76   NaN  13.28   47.76  100.00  0.24  11.90  3.75  22.03
# 2015.0           27.78   NaN   8.52   16.82  118.90  0.12   6.25  1.14  16.35
# 2016.0           15.14   NaN   5.25    3.60   69.25   NaN   4.25  0.18   4.60
#
# platform          X360   XOne
# year_of_release
# 2013.0           88.58  18.96
# 2014.0           34.74  54.07
# 2015.0           11.96  60.14
# 2016.0            1.52  26.15

# %%
fig, ax = plt.subplots(figsize=(13, 6))

x = games_after_13.pivot_table(index='year_of_release', columns='platform', values='total_sales', aggfunc='sum').index
y1 = games_after_13.pivot_table(index='year_of_release', columns='platform', values='total_sales', aggfunc='sum')['PS4']
y2 = games_after_13.pivot_table(index='year_of_release', columns='platform', values='total_sales', aggfunc='sum')['PS3']
y3 = games_after_13.pivot_table(index='year_of_release', columns='platform', values='total_sales', aggfunc='sum')['XOne']
y4 = games_after_13.pivot_table(index='year_of_release', columns='platform', values='total_sales', aggfunc='sum')['3DS']
y5 = games_after_13.pivot_table(index='year_of_release', columns='platform', values='total_sales', aggfunc='sum')['X360']
y6 = games_after_13.pivot_table(index='year_of_release', columns='platform', values='total_sales', aggfunc='sum')['WiiU']
y7 = games_after_13.pivot_table(index='year_of_release', columns='platform', values='total_sales', aggfunc='sum')['PC']
y8 = games_after_13.pivot_table(index='year_of_release', columns='platform', values='total_sales', aggfunc='sum')['PSV']
y9 = games_after_13.pivot_table(index='year_of_release', columns='platform', values='total_sales', aggfunc='sum')['Wii']
y10 = games_after_13.pivot_table(index='year_of_release', columns='platform', values='total_sales', aggfunc='sum')['PSP']
y11 = games_after_13.pivot_table(index='year_of_release', columns='platform', values='total_sales', aggfunc='sum')['DS']


ax.plot(x, y1, label = 'PS4')
ax.plot(x, y2, label = 'PS3')
ax.plot(x, y3, label = 'XOne')
ax.plot(x, y4, label = '3DS')
ax.plot(x, y5, label = 'X360')
ax.plot(x, y6, label = 'WiiU')
ax.plot(x, y7, label = 'PC')
ax.plot(x, y8, label = 'PSV')
ax.plot(x, y9, label = 'Wii')
ax.plot(x, y10, label = 'PSP')
ax.plot(x, y11, label = 'DS')

#Меняю подписи к годам для того, что бы было проще читать график(все происходящее в течении года на графике происходит после отметки года)
ax.set_xticklabels([0, 2014, 2014.5, 2015, 2015.5, 2016, 2016.5, 2017])

ax.set_title('Продажи на платформы по годам (миллионы копий)', size = 15)
ax.set_ylabel('Миллионы проданных копий')
ax.set_xlabel('Год')

ax.legend()

plt.show()
# Out:
# /var/folders/x5/shnp329907331sz0s0n6_20m0000gn/T/ipykernel_23143/809381349.py:30: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels([0, 2014, 2014.5, 2015, 2015.5, 2016, 2016.5, 2017])

# %% [markdown]
# По таблице и графику видно, что 2016 год был для всех тяжелым. На всех платформах произошел спад. Но видно какие были самыми перспективными до 2016 года. Это `PS4` и `XOne`. Возможно стоит делать ставку на эти две платформы в 2017 году.

# %% [markdown]
# Сделаем датафрейм только с платформами `PS4` и `XOne`.

# %%
games_research = games_after_13.query('platform == ("PS4", "XOne")')

# %% [markdown]
# ### График «ящик с усами» по глобальным продажам игр в разбивке по платформам

# %%
fig, ax = plt.subplots(nrows= 1 , ncols= 2, figsize=(13, 10))
fig.suptitle('Глобальные продажи по платформам после 2013 года (миллионы копий)', size = 15)

ax[0].boxplot(games_research.query('platform == "PS4"')['total_sales'])
ax[1].boxplot(games_research.query('platform == "XOne"')['total_sales'])


ax[0].set_title('PS4', size = 15)
ax[1].set_title('XOne', size = 15)
ax[0].set_ylabel('Миллионы проданных копий')
ax[1].set_ylabel('Миллионы проданных копий')

plt.show()

# %%
print('PS4\n',
    games_research.query('platform == "PS4"')['total_sales'].describe(), 
    '\nXOne\n', 
    games_research.query('platform == "XOne"')['total_sales'].describe()
)
# Out:
# PS4
#  count    392.000000
# mean       0.801378
# std        1.609456
# min        0.010000
# 25%        0.060000
# 50%        0.200000
# 75%        0.730000
# max       14.630000
# Name: total_sales, dtype: float64
# XOne
#  count    247.000000
# mean       0.645020
# std        1.036139
# min        0.010000
# 25%        0.060000
# 50%        0.220000
# 75%        0.685000
# max        7.390000
# Name: total_sales, dtype: float64

# %% [markdown]
# По количеству продаж `PS4` - лидирует(392 против 247) так же как и по общей сумме. При этом медиана на уровне 200 проданных копий у `PS4` и 220 тыс у `XOne`. Что говорит о том, что средняя продажа на `XOne` выше. Большая часть продаж игр находится на уровне 730 тыс копий у `PS4` и 685 тыс у `XOne`. Есть выбросы: на `PS4` значения от 730 тыс до 14.63 млн проданных копий, против 685 тыс. - 7.39 млн у `XOne`. Эти выбросы говорят о том, что на `PS4` игры продаются лучше. Для проверки этого построим таблицу для сравнения игр на разных платформах.

# %%
games_research.query('total_sales > 3 & name.duplicated(False)').sort_values('name')
# Out:
#                                      name platform  year_of_release  \
# 396            assassin's creed syndicate      PS4           2015.0
# 304               assassin's creed: unity      PS4           2014.0
# 373               assassin's creed: unity     XOne           2014.0
# 305                 batman: arkham knight      PS4           2015.0
# 289                         battlefield 1      PS4           2016.0
# 357                         battlefield 4      PS4           2013.0
# 92         call of duty: advanced warfare      PS4           2014.0
# 179        call of duty: advanced warfare     XOne           2014.0
# 31              call of duty: black ops 3      PS4           2015.0
# 99              call of duty: black ops 3     XOne           2015.0
# 323                  call of duty: ghosts      PS4           2013.0
# 245        call of duty: infinite warfare      PS4           2016.0
# 398                               destiny     XOne           2014.0
# ...

# %% [markdown]
# В таблице видно, что игры на платформе `PS4` продаются намного лучше. Возможно это связано с большей популярностью этой платформы. Мы построили таблицу с повторяющимися названиями игр и значениями глобальных продаж больше 3 млн проданных копий. Если в эту таблицу не попали игры с платформы `XOne` - это значит, что продажи у них меньше 3 млн. Это подтверждает, то что платформа `PS4` на данный момент самая перспективная.

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# ✍
# Не стоит ограничивать диаграмму размаха, нам нужно посмотреть все платформы из актуального периода. Также, прошу тебя построить одну диаграмму с несколькими ящиками.
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента v.1</b>
#
# Наш преподователь рекомендовал продолжать исследование по тем платформам, которые выбрали. Но в целом не сложно сделать одну диаграмму с несколькими ящиками, дальше я это уже делал.
# Ниже диаграмма с комментариями.
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍
# Благодарю.
#
# Тут речь идет не о типе платформ, а о размере выборки. Если в выборке остаются 5 или меньше консолей, то задача с определением топ-5 по регионам начинает терять смысл.
# </div>

# %%
fig, ax = plt.subplots(figsize=(13, 10))
fig.suptitle('Глобальные продажи по платформам после 2013 года (миллионы копий)', size = 15)

platforms = []
platform_name = []
for p in games_after_13['platform'].unique():
    platforms.append(games_after_13.query('platform == @p')['total_sales'].values)
    platform_name.append(p)
ax.boxplot(platforms)

ax.set_ylabel('Миллионы проданных копий')
ax.set_xticklabels(platform_name)

ax.grid()

plt.show()

# %% [markdown]
# Очень много выбросов. Самый высокий у `PS3` - выше 20 млн проданных копий. Далее `X360`, потом `PS4` и `3DS`. Такие высокие выбросы у `3DS` удивляют учитывая, что это компактные игровые устройства. Посмотрим на ящики поближе, сократив ось `y` до 3 млн.

# %%
fig, ax = plt.subplots(figsize=(13, 10))
fig.suptitle('Глобальные продажи по платформам после 2013 года (миллионы копий)', size = 15)

platforms = []
platform_name = []
for p in games_after_13['platform'].unique():
    platforms.append(games_after_13.query('platform == @p')['total_sales'].values)
    platform_name.append(p)
ax.boxplot(platforms)

ax.set_ylabel('Миллионы проданных копий')
ax.set_ylim(0,3)
ax.set_xticklabels(platform_name)

minor_ticks = np.arange(0, 3, 0.1)
ax.set_yticks(minor_ticks, minor=True)

ax.grid(which='minor', alpha=0.2)
ax.grid(which='major', alpha=0.5)

plt.show()

# %% [markdown]
# Разберем по отдельности все платформы:
# - `PSP` очень маленький ящик и низкая медиана, плюс выбросы похоже не доходят до 300 тыс продаж. Самый низкий показаатель в сравнении с остальными. Это потому что весь успех у этой платформы был до 2013 года.
# - `PSV` эта платформа более успешная после 2013 года, но ранее у `PSP` продажи были выше, хотя там и время было другое. Это видно на графике продаж по годам.
# - `DS` эта платформа так же была популярна до 2013 года, поэтому данные не актуальны.
# - `3DS` как писали выше, имеет очень высокие выбросы для такого скромного(в сравнении с остальными лидерами) межквартильного размаха. Но нужно понимать, что платформа в своем роде уникальна, у нее своя ниша и для этих условий у нее очень хорошие показатели.
# - `PC` - имеет показатели на уровне `3DS`. Видимо пользователи предпочитают джойстики больше, чем клавиатуру и мышку.
# - `Wii` была популярна до 2013 года. В таблице с продажами по платформам и годам видно, что в 2006 году платформа взлетела и достигла высоких показателей, но дальше шла только вниз, но тем не менее имеет хорошие показатели.
# - `WiiU` не получила такой популярности как `Wii`, но все равно умеет достаточно высокую медиану и межквартильный размах.
# - `X360` имеет самую высокую медиану, что значит, что в среднем игра выпущенная на этой платформе продается лучше, чем на остальных. Но если посмотреть таблицу с продажами по годам, то на этой платформе был очень удачный 2013 год, остальные были хуже.
# - `X0ne` медиана на 2 месте среди всех платформ, при том, что платформа новая. В целом платформа имеет хорошие показатели.
# - `PS3` имеет самую низкую медиану среди платформ не компактных устройств и не персонального компьютера. При этом имеет высокие выбросы. Но стоит отметить, что платформа уже прожила свой жизненый цикл.
# - `PS4` имеет самый большой размах усов и хорошую плотность выбросов до 2 млн. Медиана ниже, чем у `X0ne` и `X360`, но первый это прямой и свежий конкурент, а второй уже устаревает.
#
# Если опираться на показатели продаж и актуальность платформ, то на перспективу стоит выбрать `PS4` и `X0ne`.

# %% [markdown]
# ### Как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков

# %%
fig, ax = plt.subplots(nrows= 2 , ncols= 1,figsize=(15, 10))

ax[0].scatter(games_research.query('platform == "PS4"')['total_sales'], 
           games_research.query('platform == "PS4"')['critic_score'], label='PS4')
ax[0].scatter(games_research.query('platform == "XOne"')['total_sales'], 
           games_research.query('platform == "XOne"')['critic_score'], label='XOne')
ax[1].scatter(games_research.query('platform == "PS4"')['total_sales'], 
           games_research.query('platform == "PS4"')['user_score'], label='PS4')
ax[1].scatter(games_research.query('platform == "XOne"')['total_sales'], 
           games_research.query('platform == "XOne"')['user_score'], label='XOne')

ax[0].set_title('Влияние отзывов критиков на продажи по платформам', size = 15)
ax[0].set_ylabel('Баллы оценки критиков')
ax[0].set_xlabel('Миллионы проданных копий')
ax[1].set_title('Влияние отзывов пользователей на продажи по платформам', size = 15)
ax[1].set_ylabel('Баллы оценки пользователей')
ax[1].set_xlabel('Миллионы проданных копий')

ax[0].grid()
ax[1].grid()

ax[0].legend()
ax[1].legend()

plt.show()

# %%
print(
    'Кореляция между отзывами критиков и продажами на PS4 =', 
    games_research.query('platform == "PS4"')['total_sales']
    .corr(games_research.query('platform == "PS4"')['critic_score']), 
    '\nКореляция между отзывами пользователей и продажами на PS4 =', 
    games_research.query('platform == "PS4"')['total_sales']
    .corr(games_research.query('platform == "PS4"')['user_score']), 
    '\nКореляция между отзывами критиков и продажами на XOne =', 
    games_research.query('platform == "XOne"')['total_sales']
    .corr(games_research.query('platform == "XOne"')['critic_score']), 
    '\nКореляция между отзывами пользователей и продажами на XOne =', 
    games_research.query('platform == "XOne"')['total_sales']
    .corr(games_research.query('platform == "XOne"')['user_score'])
)
# Out:
# Кореляция между отзывами критиков и продажами на PS4 = 0.406567902061781
# Кореляция между отзывами пользователей и продажами на PS4 = -0.031957110204556424
# Кореляция между отзывами критиков и продажами на XOne = 0.41699832800840175
# Кореляция между отзывами пользователей и продажами на XOne = -0.06892505328279412

# %% [markdown]
# На диаграмме рассеяния видна разница влияния оценок критиков и пользователей на продажи игр. На диаграмме с оценками пользователей видно, что продажи больше 2 млн начинаются с 3 баллов(из 10),а продажи около 4 млн есть до оценки в 4 балла(из 10). В то время как на диаграмме с оценками критиков продажи в 2 млн начинаются с оценки выше 50(из 100), а 4 млн стартуют с оценки выше 70 баллов(из 100).
#
# Обращая внимание на кореляции можно понять, что значения 0.40 и 0.41 показывают влияние отзывов критиков на продажи, в то время как -0.03 и -0.06 почти не имеют влияния, а если и имеют, то отрицательное.
#
# Посмотрев еще раз на диаграмму с оценками критиков можно сделать главный вывод. Один из критериев успеха продаж видео игр - это оценки критиков выше 70 баллов!

# %% [markdown]
# ### Соотношение выводов с продажами игр на других платформах

# %% [markdown]
# Построим диаграмму рассеивания по влиянию отзывов критиков(так как отзывы пользователей не влияют) на продажи игр по платформам.

# %%
fig, ax = plt.subplots(figsize=(15, 10))

for p in games_after_13['platform'].unique():
    ax.scatter(games_after_13.query('platform == @p')['total_sales'], 
               games_after_13.query('platform == @p')['critic_score'], label=p)


ax.set_title('Влияние отзывов критиков на продажи по платформам', size = 15)
ax.set_ylabel('Баллы оценки критиков')
ax.set_xlabel('Миллионы проданных копий')

ax.grid()

ax.legend()

plt.show()

# %% [markdown]
# На диаграмме выделяются три точки больше 10 млн проданных копий при оценке около 100 баллов. Возможно это одна игра на разных платформах?

# %%
games_after_13.query('total_sales > 10').sort_values('name')
# Out:
#                                          name platform  year_of_release  \
# 31                  call of duty: black ops 3      PS4           2015.0
# 60                       call of duty: ghosts     X360           2013.0
# 16                         grand theft auto v      PS3           2013.0
# 23                         grand theft auto v     X360           2013.0
# 42                         grand theft auto v      PS4           2014.0
# 47  pokemon omega ruby/pokemon alpha sapphire      3DS           2014.0
# 33                        pokemon x/pokemon y      3DS           2013.0
#
#            genre  na_sales  eu_sales  jp_sales  other_sales  critic_score  \
# 31       Shooter      6.03      5.86      0.36         2.38           NaN
# 60       Shooter      6.73      2.56      0.04         0.91          73.0
# 16        Action      7.02      9.09      0.98         3.96          97.0
# 23        Action      9.66      5.14      0.06         1.41          97.0
# ...

# %% [markdown]
# Игра `Grand Theft Auto V` имеет высокие оценки и у нее высокие показатели продаж. Так же в таблицу с продажами больше 10 млн копий попали игры `Call of Duty: Black Ops 3`, `Call of Duty: Ghosts`, `Pokemon Omega Ruby/Pokemon Alpha Sapphire`, `Pokemon X/Pokemon Y`. `Call of Duty: Ghosts` имеет оценку 73 балла и продажи 10.24 млн копий - это высокий показатель для такой оценки. Остальные игры в таблице - без оценок. 2 игры про покемонов на `3DS` тоже имеют хорошие продажи. Может зря исключили эту платформу из основной выборки? .Посмотрим много ли оценок у игр на этой платформе.

# %%
print('Всего игр на платформе 3DS -', len(games_after_13.query('platform == "3DS"')), 
 '\nИгр с оценкой на платформе 3DS -', games_after_13.query('platform == "3DS"')['critic_score'].count()
)
# Out:
# Всего игр на платформе 3DS - 303
# Игр с оценкой на платформе 3DS - 71

# %% [markdown]
# Большая часть игр без оценок. Возможно у этой платформы своя ниша и оценки собираются по другой системе или на других ресурсах. посмотрим на показатели оценок критиков и продаж.

# %%
games_after_13.query('platform == "3DS"')['critic_score'].describe()
# Out:
# count    71.000000
# mean     68.338028
# std      13.093012
# min      26.000000
# 25%      61.000000
# 50%      69.000000
# 75%      78.500000
# max      91.000000
# Name: critic_score, dtype: float64

# %%
games_after_13.query('platform == "3DS"')['total_sales'].describe()
# Out:
# count    303.000000
# mean       0.472772
# std        1.381347
# min        0.010000
# 25%        0.040000
# 50%        0.090000
# 75%        0.280000
# max       14.600000
# Name: total_sales, dtype: float64

# %% [markdown]
# Большая часть продаж до 280 тыс копий. На платформах `PS4` и `XOne` этот показатель на 730 тыс и 685 тыс копий соответственно. это большая разница, говорящая о том, что на `3DS` скорее всего публика численно меньше и от этого продаж там меньше и успех некоторых игр на этой платформе не показательный.

# %% [markdown]
# На каждой платформе оценки критиков имеют вляние на продажи.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Верно. Оценка критиков имеет слабое влияние на продажи, оценка пользователей на продажи не влияет.
# </div>

# %% [markdown]
# ### Общее распределение игр по жанрам

# %%
fig, ax = plt.subplots(figsize=(13, 6))


ax.bar(games_research.groupby('genre')['total_sales'].sum().sort_values().index,
       games_research.groupby('genre')['total_sales'].sum().sort_values())

ax.set_title('Продажи  игр по жанрам (миллионы копий)', size = 15)
ax.set_ylabel('Миллионы проданных копий')
ax.set_xlabel('Жанр')
ax.grid()
plt.show()

# %% [markdown]
# Видна тройка лидеров по жанрам - это `Sports`, `Action`, `Shooter`. Где первые два места имеют на треть больше продаж, чем третее место. На графике кажется, что `Action` и `Shooter` безоговорочные лидеры рынка. `Puzzle`, `Strategy`, `Simulation` В самом низу рынка. Посмотрим данные на диаграмме размаха.

# %%
fig, ax = plt.subplots(figsize=(13, 10))
fig.suptitle('Глобальные продажи по жанрам после 2013 года (миллионы копий)', size = 15)

genres = []
genres_name = []
for g in games_research['genre'].unique():
    genres.append(games_research.query('genre == @g')['total_sales'].values)
    genres_name.append(g)
ax.boxplot(genres)

ax.set_ylabel('Миллионы проданных копий')
ax.set_ylim(0,6)
ax.set_xticklabels(genres_name)

ax.grid()

plt.show()

# %% [markdown]
# На диаграмме видно, что жанр `Shooter` лидер, а вот `Action` не совсем. У `Action` есть много выбросов, при этом медиана находится довольно низко, в то время как `Sports` имеет межквартильный размах в два раза больше, уровень медианы выше, что говорит о том, что в этом жанре больше стабильных продаж.
#
# Жанр `Shooter` самый перспективный, `Sports` занимает второе место, `Racing` - третье место. Так как у `Action` много продаж его можно поставить на третье место.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Верно. Общие продажи - плохая метрика для поиска наиболее прибыльного жанра. За высокими показателями общих продаж может скрываться множество мелких игр с низкими продажами. Или 2-3 звезды и куча провалов. Лучше найти жанр, где игры стабильно приносят высокий доход - для этого стоит рассматривать средние или медианные продажи.
# </div>

# %% [markdown]
# ## Портреты пользователей

# %% [markdown]
# ### Продажи игр на разных платформах по регионам

# %%
print('Продажи в Северной Америке\n',
    games_after_13.groupby('platform')['na_sales'].sum().sort_values(), 
      '\nПродажи в Европе\n',
    games_after_13.groupby('platform')['eu_sales'].sum().sort_values(), 
      '\nПродажи в Японии\n',
    games_after_13.groupby('platform')['jp_sales'].sum().sort_values(), 
      '\nПродажи в других странах\n',
    games_after_13.groupby('platform')['other_sales'].sum().sort_values()
)
# Out:
# Продажи в Северной Америке
#  platform
# PSP       0.00
# DS        0.57
# PSV       5.04
# Wii       6.56
# PC       11.19
# WiiU     29.21
# 3DS      38.20
# PS3      63.50
# X360     81.66
# XOne     93.12
# PS4     108.74
# Name: na_sales, dtype: float64
# Продажи в Европе
#  platform
# PSP       0.17
# DS        0.85
# Wii       5.93
# PSV       6.10
# WiiU     19.85
# PC       25.84
# 3DS      30.96
# X360     42.52
# XOne     51.59
# PS3      67.81
# PS4     141.09
# Name: eu_sales, dtype: float64
# Продажи в Японии
#  platform
# DS       0.00
# PC       0.00
# Wii      0.05
# XOne     0.34
# X360     0.51
# PSP      3.53
# WiiU    10.88
# PS4     15.96
# PSV     18.59
# PS3     23.35
# 3DS     67.81
# Name: jp_sales, dtype: float64
# Продажи в других странах
#  platform
# PSP      0.04
# DS       0.12
# Wii      1.12
# PC       3.03
# PSV      3.26
# WiiU     4.69
# 3DS      6.28
# X360    12.11
# XOne    14.27
# PS3     26.77
# PS4     48.35
# ...

# %%
fig, ax = plt.subplots(2, 2, figsize=(15, 15))
fig.suptitle('Продажи на платформах по регионам после 2013 года (миллионы копий)', size = 15)


ax[0,0].pie(games_after_13.groupby('platform')['na_sales'].sum().sort_values(), 
            labels = games_after_13.groupby('platform')['na_sales'].sum().sort_values().index, 
            autopct='%.0f%%', radius=1)
ax[0,1].pie(games_after_13.groupby('platform')['eu_sales'].sum().sort_values(), 
            labels = games_after_13.groupby('platform')['eu_sales'].sum().sort_values().index, 
            autopct='%.0f%%', radius=1)
ax[1,0].pie(games_after_13.groupby('platform')['jp_sales'].sum().sort_values(), 
            labels = games_after_13.groupby('platform')['jp_sales'].sum().sort_values().index, 
            autopct='%.0f%%', radius=1)
ax[1,1].pie(games_after_13.groupby('platform')['other_sales'].sum().sort_values(), 
            labels = games_after_13.groupby('platform')['other_sales'].sum().sort_values().index, 
            autopct='%.0f%%', radius=1)

ax[0,0].set_title('Северная Америка', size = 15)
ax[0,1].set_title('Европа', size = 15)
ax[1,0].set_title('Япония', size = 15)
ax[1,1].set_title('Другие страны', size = 15)

plt.show()

# %%
fig, ax = plt.subplots(2, 2, figsize=(15, 10))
fig.suptitle('Продажи на платформах по регионам после 2013 года (миллионы копий)', size = 15)


ax[0,0].bar(games_after_13.groupby('platform')['na_sales'].sum().sort_values().index,
       games_after_13.groupby('platform')['na_sales'].sum().sort_values())
ax[0,1].bar(games_after_13.groupby('platform')['eu_sales'].sum().sort_values().index,
       games_after_13.groupby('platform')['eu_sales'].sum().sort_values())
ax[1,0].bar(games_after_13.groupby('platform')['jp_sales'].sum().sort_values().index,
       games_after_13.groupby('platform')['jp_sales'].sum().sort_values())
ax[1,1].bar(games_after_13.groupby('platform')['other_sales'].sum().sort_values().index,
       games_after_13.groupby('platform')['other_sales'].sum().sort_values())

ax[0,0].set_title('Северная Америка', size = 15)
ax[0,0].set_ylabel('Миллионы проданных копий')
ax[0,0].set_xlabel('Платформа')
ax[0,0].grid()
ax[0,1].set_title('Европа', size = 15)
ax[0,1].set_ylabel('Миллионы проданных копий')
ax[0,1].set_xlabel('Платформа')
ax[0,1].grid()
ax[1,0].set_title('Япония', size = 15)
ax[1,0].set_ylabel('Миллионы проданных копий')
ax[1,0].set_xlabel('Платформа')
ax[1,0].grid()
ax[1,1].set_title('Другие страны', size = 15)
ax[1,1].set_ylabel('Миллионы проданных копий')
ax[1,1].set_xlabel('Платформа')
ax[1,1].grid()

plt.show()

# %% [markdown]
# Так же посмотрим суммы продаж по регионам.

# %%
print('Продажи в Северной Америке -', games_after_13['na_sales'].sum(), 
      '\nПродажи в Японии - ', games_after_13['jp_sales'].sum(), 
      '\nПродажи в Северной Америке и Японии -', (games_after_13['na_sales'].sum() + games_after_13['jp_sales'].sum()), 
      '\nПродажи в Европе - ', games_after_13['eu_sales'].sum(), 
      '\nПродажи в других странах - ', games_after_13['other_sales'].sum(), 
      '\nПродажи в Европе и других странах - ', (games_after_13['eu_sales'].sum() + games_after_13['other_sales'].sum()),
     )
# Out:
# Продажи в Северной Америке - 437.79
# Продажи в Японии -  141.02
# Продажи в Северной Америке и Японии - 578.8100000000001
# Продажи в Европе -  392.71
# Продажи в других странах -  120.04
# Продажи в Европе и других странах -  512.75

# %% [markdown]
# На графиках видно, что `PSP`, самая не популярная платформа, кроме Японии. Видимо живет она только за счет этого региона. Там же самая популярная платформа это `3DS`. На втором месте по продажам `PS3`, который обогнал `PS4`, который занимает первые места в других регионах. И третье место занимает `PSV`, который является портативной консолью, как и `PSP` и `3DS`. В Японии видимо очень популярны портативные устройства для игр.
#
# Посмотрим на другие регионы. Везде первое место однозначно занимает `PS4`. Дальше желания разделяются. В Северной Америке `XOne` второе место и `X360` третье место, в то время как в Европе и других странах второе место `PS3` и `XOne` третье место.
#
# В целом Европа и другие страны очень похожи по предпочтениям. В Северной Америке кроме `PS4`, популярны `XOne` и `X360`. Четвертое и пятое место делят `X360`, `3DS`, `WiiU`.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Верная интерпретация полученных данных.
# </div>

# %% [markdown]
# ### Продажи игр с разными жанрами по регионам

# %%
print('Продажи в Северной Америке\n',
    games_after_13.groupby('genre')['na_sales'].sum().sort_values(), 
      '\nПродажи в Европе\n',
    games_after_13.groupby('genre')['eu_sales'].sum().sort_values(), 
      '\nПродажи в Японии\n',
    games_after_13.groupby('genre')['jp_sales'].sum().sort_values(), 
      '\nПродажи в других странах\n',
    games_after_13.groupby('genre')['other_sales'].sum().sort_values()
)
# Out:
# Продажи в Северной Америке
#  genre
# Puzzle            0.83
# Strategy          3.28
# Simulation        4.86
# Adventure         7.14
# Racing           12.96
# Fighting         15.55
# Platform         18.14
# Misc             27.49
# Role-Playing     46.40
# Sports           65.27
# Shooter         109.74
# Action          126.13
# Name: na_sales, dtype: float64
# Продажи в Европе
#  genre
# Puzzle            1.00
# Strategy          4.22
# Adventure         8.25
# Fighting          8.55
# Simulation       10.92
# Platform         15.58
# Misc             20.04
# Racing           20.19
# Role-Playing     36.97
# Sports           60.52
# Shooter          87.86
# Action          118.61
# Name: eu_sales, dtype: float64
# Продажи в Японии
#  genre
# Puzzle           1.18
# Strategy         1.77
# Racing           2.30
# Simulation       4.52
# Platform         4.79
# Sports           5.41
# Adventure        5.82
# Shooter          6.61
# Fighting         7.65
# Misc             9.44
# ...

# %%
fig, ax = plt.subplots(2, 2, figsize=(15, 15))
fig.suptitle('Продажи на платформах по регионам после 2013 года (миллионы копий)', size = 15)


ax[0,0].pie(games_after_13.groupby('genre')['na_sales'].sum().sort_values(), 
            labels = games_after_13.groupby('genre')['na_sales'].sum().sort_values().index, 
            autopct='%.0f%%', radius=1)
ax[0,1].pie(games_after_13.groupby('genre')['eu_sales'].sum().sort_values(), 
            labels = games_after_13.groupby('genre')['eu_sales'].sum().sort_values().index, 
            autopct='%.0f%%', radius=1)
ax[1,0].pie(games_after_13.groupby('genre')['jp_sales'].sum().sort_values(), 
            labels = games_after_13.groupby('genre')['jp_sales'].sum().sort_values().index, 
            autopct='%.0f%%', radius=1)
ax[1,1].pie(games_after_13.groupby('genre')['other_sales'].sum().sort_values(), 
            labels = games_after_13.groupby('genre')['other_sales'].sum().sort_values().index, 
            autopct='%.0f%%', radius=1)

ax[0,0].set_title('Северная Америка', size = 15)
ax[0,1].set_title('Европа', size = 15)
ax[1,0].set_title('Япония', size = 15)
ax[1,1].set_title('Другие страны', size = 15)

plt.show()

# %%
fig, ax = plt.subplots(4, 1, figsize=(15, 20))
fig.suptitle('Продажи на платформах по регионам после 2013 года (миллионы копий)', size = 15)


ax[0].bar(games_after_13.groupby('genre')['na_sales'].sum().sort_values().index,
       games_after_13.groupby('genre')['na_sales'].sum().sort_values())
ax[1].bar(games_after_13.groupby('genre')['eu_sales'].sum().sort_values().index,
       games_after_13.groupby('genre')['eu_sales'].sum().sort_values())
ax[2].bar(games_after_13.groupby('genre')['jp_sales'].sum().sort_values().index,
       games_after_13.groupby('genre')['jp_sales'].sum().sort_values())
ax[3].bar(games_after_13.groupby('genre')['other_sales'].sum().sort_values().index,
       games_after_13.groupby('genre')['other_sales'].sum().sort_values())

ax[0].set_title('Северная Америка', size = 15)
ax[0].set_ylabel('Миллионы проданных копий')
ax[0].set_xlabel('Жанр')
ax[0].grid()
ax[1].set_title('Европа', size = 15)
ax[1].set_ylabel('Миллионы проданных копий')
ax[1].set_xlabel('Жанр')
ax[1].grid()
ax[2].set_title('Япония', size = 15)
ax[2].set_ylabel('Миллионы проданных копий')
ax[2].set_xlabel('Жанр')
ax[2].grid()
ax[3].set_title('Другие страны', size = 15)
ax[3].set_ylabel('Миллионы проданных копий')
ax[3].set_xlabel('Жанр')
ax[3].grid()

plt.show()

# %% [markdown]
# Япония опять отличилась. Жанр `Role-Playing` занимает там первое место. Хотя в Северной Америке, Европе и других регионах он только на 4-м месте. Второе место `Action`, который является первым в остальном мире. Далее по убывающей `Misc`, `Fighting`, `Shooter`.
#
# В Северной Аммерике, Европе и других странах первое место - `Action`, второе - `Shooter`, третье - `Sports`, четвертое - `Role-Playing` и пятое - `Misc`.
#
# В жанрах весь мир, кроме Японии сходится.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Согласен, NA и EU во многом схожи, в то время, как Япония более самобытна.
# </div>

# %% [markdown]
# ### Влияет ли рейтинг ESRB на продажи в отдельном регионе?

# %%
print('Продажи в Северной Америке\n',
    games_after_13.groupby('rating')['na_sales'].sum().sort_values(), 
      '\nПродажи в Европе\n',
    games_after_13.groupby('rating')['eu_sales'].sum().sort_values(), 
      '\nПродажи в Японии\n',
    games_after_13.groupby('rating')['jp_sales'].sum().sort_values(), 
      '\nПродажи в других странах\n',
    games_after_13.groupby('rating')['other_sales'].sum().sort_values()
)
# Out:
# Продажи в Северной Америке
#  rating
# T           51.98
# E10+        56.38
# unknown     72.54
# E           81.71
# M          175.18
# Name: na_sales, dtype: float64
# Продажи в Европе
#  rating
# T           43.68
# E10+        45.20
# unknown     61.19
# E           85.49
# M          157.15
# Name: eu_sales, dtype: float64
# Продажи в Японии
#  rating
# E10+        6.27
# M          15.11
# E          15.98
# T          22.84
# unknown    80.82
# Name: jp_sales, dtype: float64
# Продажи в других странах
#  rating
# E10+       13.21
# T          14.98
# unknown    17.95
# E          23.18
# M          50.72
# Name: other_sales, dtype: float64

# %%
fig, ax = plt.subplots(2, 2, figsize=(15, 15))
fig.suptitle('Продажи на платформах по регионам после 2013 года (миллионы копий)', size = 15)


ax[0,0].pie(games_after_13.groupby('rating')['na_sales'].sum().sort_values(), 
            labels = games_after_13.groupby('rating')['na_sales'].sum().sort_values().index, 
            autopct='%.0f%%', radius=1)
ax[0,1].pie(games_after_13.groupby('rating')['eu_sales'].sum().sort_values(), 
            labels = games_after_13.groupby('rating')['eu_sales'].sum().sort_values().index, 
            autopct='%.0f%%', radius=1)
ax[1,0].pie(games_after_13.groupby('rating')['jp_sales'].sum().sort_values(), 
            labels = games_after_13.groupby('rating')['jp_sales'].sum().sort_values().index, 
            autopct='%.0f%%', radius=1)
ax[1,1].pie(games_after_13.groupby('rating')['other_sales'].sum().sort_values(), 
            labels = games_after_13.groupby('rating')['other_sales'].sum().sort_values().index, 
            autopct='%.0f%%', radius=1)

ax[0,0].set_title('Северная Америка', size = 15)
ax[0,1].set_title('Европа', size = 15)
ax[1,0].set_title('Япония', size = 15)
ax[1,1].set_title('Другие страны', size = 15)

plt.show()

# %%
fig, ax = plt.subplots(2, 2, figsize=(15, 10))
fig.suptitle('Продажи на платформах по регионам после 2013 года (миллионы копий)', size = 15)


ax[0,0].bar(games_after_13.groupby('rating')['na_sales'].sum().sort_values().index,
       games_after_13.groupby('rating')['na_sales'].sum().sort_values())
ax[0,1].bar(games_after_13.groupby('rating')['eu_sales'].sum().sort_values().index,
       games_after_13.groupby('rating')['eu_sales'].sum().sort_values())
ax[1,0].bar(games_after_13.groupby('rating')['jp_sales'].sum().sort_values().index,
       games_after_13.groupby('rating')['jp_sales'].sum().sort_values())
ax[1,1].bar(games_after_13.groupby('rating')['other_sales'].sum().sort_values().index,
       games_after_13.groupby('rating')['other_sales'].sum().sort_values())

ax[0,0].set_title('Северная Америка', size = 15)
ax[0,0].set_ylabel('Миллионы проданных копий')
ax[0,0].set_xlabel('Рейтинг ESRB')
ax[0,0].grid()
ax[0,1].set_title('Европа', size = 15)
ax[0,1].set_ylabel('Миллионы проданных копий')
ax[0,1].set_xlabel('Рейтинг ESRB')
ax[0,1].grid()
ax[1,0].set_title('Япония', size = 15)
ax[1,0].set_ylabel('Миллионы проданных копий')
ax[1,0].set_xlabel('Рейтинг ESRB')
ax[1,0].grid()
ax[1,1].set_title('Другие страны', size = 15)
ax[1,1].set_ylabel('Миллионы проданных копий')
ax[1,1].set_xlabel('Рейтинг ESRB')
ax[1,1].grid()

plt.show()

# %% [markdown]
# В Японии самые популярные игры категории `T` - Teen для лиц от 13 лет. Проекты из данной категории могут содержать насилие, непристойные сцены, грубый юмор, в меру откровенное сексуальное содержимое, кровь или нечастое использование ненормативной лексики. На втором месте `E` - Everyone — «Для всех»: Содержание вполне подходит для всех возрастов (ранее с 6 лет). Такие игры могут понравиться и взрослым. Игры с этим рейтингом могут содержать минимальное насилие, в основном «мультяшного» характера. Третье место - `M` - Mature Для взрослых: Материалы игры не подходят для лиц младше 17 лет. Проекты с данным рейтингом могут содержать жестокое насилие, большое количество крови с расчленением, непристойные сексуальные сцены или грубую ненормативную лексику. Четвертое место - `E10+` Для всех от 10 лет и старше: Проекты с данным рейтингом могут содержать больше мультипликационного или мягкого насилия, или несколько откровенные сцены, или минимальное количество крови.
# В Северной Америке и Европе первое место - `M`, второе - `E`, третье - `E10+`, четвертое - `T`. При этом `M` значительно отрывается на первом месте.
#
# Все кроме Японии предпочитает большее насилие и откровенные сцены в играх.

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 📝
# В процессе предобработки данных мы не учли отсутствующие значения в рейтинге ESRB, что привело к исключению игр без рейтинга из анализа. Однако анализ продаж таких игр может выявить ключевые особенности различных регионов.
#
# Изучив специфику рейтинга ESRB, становится ясно, что он применяется главным образом для игр, реализуемых в США и Канаде. Отсюда и отсутствие рейтинга для игр в других регионах. Важно помнить, что каждая цифра в датасете отражает определенные бизнес-процессы. Поэтому в процессе предобработки следует подойти к вопросу глобальнее, заменяя пропущенные значения на, например, `Unknown`, чтобы учесть все игры при последующем анализе.
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента v.1</b>
#
# Теперь графики сформировались по новым данным так как в предобработке заменил все пустые значения в колонке `rating` на `unknown`
#
# Ниже сделал новый вывод.
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍
# Да, теперь картина полная. Ты молодец!
# </div>

# %% [markdown]
# В Японии самые популярные игры с большим отрым от остальных - неизвестной категории, это значит, что игры популярные в Японии не попадают в этот рейтинг. Скорее всего у них свои рейтинги, так как в целом это специфичный рынок со своими правилами и устоями. На втором месте категория `T` - Teen для лиц от 13 лет. Проекты из данной категории могут содержать насилие, непристойные сцены, грубый юмор, в меру откровенное сексуальное содержимое, кровь или нечастое использование ненормативной лексики. На третьем месте `E` - Everyone — «Для всех»: Содержание вполне подходит для всех возрастов (ранее с 6 лет). Такие игры могут понравиться и взрослым. Игры с этим рейтингом могут содержать минимальное насилие, в основном «мультяшного» характера. Четвертое место - `M` - Mature Для взрослых: Материалы игры не подходят для лиц младше 17 лет. Проекты с данным рейтингом могут содержать жестокое насилие, большое количество крови с расчленением, непристойные сексуальные сцены или грубую ненормативную лексику. Пятое место - `E10+` Для всех от 10 лет и старше: Проекты с данным рейтингом могут содержать больше мультипликационного или мягкого насилия, или несколько откровенные сцены, или минимальное количество крови.
# В Северной Америке и Европе первое место - `M`, второе - `E`, третье - `unknown`, четвертое - `E10+`, пятое - `T`. При этом `M` значительно отрывается на первом месте.
#
# Все кроме Японии предпочитает большее насилие и откровенные сцены в играх. Рынок Японии очень самобытен и делать ставки на него не стоит, потому что преуспев в Японии, в остальном мире, можно оказаться в аутсайдерах.

# %% [markdown]
# ## Проверка гипотез

# %% [markdown]
# ### Гипотеза: Средние пользовательские рейтинги платформ Xbox One и PC одинаковые

# %% [markdown]
# Нулевая гипотеза всегда должна быть всегда со знаком равенства, а обратная со знаками не равенства(больше, меньше или не равно) В данном случае утверждение звучит: Средние пользовательские рейтинги платформ Xbox One и PC одинаковые. Это равенство, значит противопоставить этому можно неравенство. Поэтому гипотезы будут выглядеть слудеющим образом:

# %% [markdown]
# Формулировка нулевой(H0) и альтернативной(H1) гипотезы.
#
# H0: Средние пользовательские рейтинги платформ Xbox One и PC равны
#
# H1: Средние пользовательские рейтинги платформ Xbox One и PC не равны

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Гипотезы сформулированы верно.
# </div>

# %% [markdown]
# Используем метод для проверки гипотез о равенстве средних двух генеральных совокупностей `st.ttest_ind`

# %%
alpha = 0.05

results = st.ttest_ind(
    games_after_13.query('platform == "XOne"')['user_score'].dropna(), 
    games_after_13.query('platform == "PC"')['user_score'].dropna(), 
    alternative='two-sided')
print('p-значение:', results.pvalue)

if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не получилось отвергнуть нулевую гипотезу')
# Out:
# p-значение: 0.15503167687396294
# Не получилось отвергнуть нулевую гипотезу

# %% [markdown]
# Р - значение оказалось выше установленного уровня статистической значимости, поэтому понижать его нет смысла.
#
# Вывод: Средние пользовательские рейтинги платформ Xbox One и PC одинаковые

# %% [markdown]
# ### Средние пользовательские рейтинги жанров Action и Sports разные.

# %% [markdown]
# Нулевая гипотеза всегда должна быть всегда со знаком равенства, а обратная со знаками не равенства(больше, меньше или не равно) В данном случае утверждение звучит: Средние пользовательские рейтинги жанров Action и Sports разные. Это не равенство, значит противопоставить этому можно равенство. Поэтому гипотезы будут выглядеть слудеющим образом:

# %% [markdown]
# Формулировка нулевой(H0) и альтернативной(H1) гипотезы.
#
# H0: Средние пользовательские рейтинги жанров Action и Sports равны
#
# H1: Средние пользовательские рейтинги жанров Action и Sports не равны

# %% [markdown]
# Используем метод для проверки гипотез о равенстве средних двух генеральных совокупностей `st.ttest_ind`

# %%
alpha = 0.05

results = st.ttest_ind(
    games_after_13.query('genre == "Action"')['user_score'].dropna(), 
    games_after_13.query('genre == "Sports"')['user_score'].dropna(), 
    alternative='two-sided')
print('p-значение:', results.pvalue)

if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не получилось отвергнуть нулевую гипотезу')
# Out:
# p-значение: 8.11729623919141e-28
# Отвергаем нулевую гипотезу

# %% [markdown]
# Р - значение оказалось гораздо ниже установленного уровня статистической значимости, что даже если установить уровень на 0.01, то все равно Нулевую гипотезу можно отвергать.
# Вывод: Средние пользовательские рейтинги жанров Action и Sports разные

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# * Правильно, что для тестирования гипотез использован двусторонний t-тест Стьюдента.
#
# * Хорошо, что использован параметр отфильтровывющий пропуски.
# </div>

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 📝
# Также можно вывести не только pvalue, но еще и средние значения выборок, которые мы изучаем. Это позволит нам проверить не ошиблись ли мы, если они расходятся с тестом Стьюдента.
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента v.1</b>
#
# Согласен, лишним не будет!
#
# Ниже вывел средние выборок.
# </div>

# %%
print('Жанр "Action"\n', games_after_13.query('genre == "Action"')['user_score'].dropna().mean(), 
      '\nЖанр "Sports"\n', games_after_13.query('genre == "Sports"')['user_score'].dropna().mean())
# Out:
# Жанр "Action"
#  6.8375
# Жанр "Sports"
#  5.238124999999999

# %% [markdown]
# Средние значения выборок по жанрам и правда не равны.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍
#
# </div>

# %% [markdown]
# ## Вывод

# %% [markdown]
# Мы получили данные о видеоиграх, содержащие информацию о названии, годе выпуска, платформе, жанре, количестве продаж и оценках пользоватлей и критиков. В данных были потери и неправильные типы данных.
#
# По возможности все было восстановлено на 2 шаге.
#
# Был проведен исследовательский анализ данных. Изучили:
# - Количество выпущенных игр в разные годы. Определили, что стоит опираться на данные с 2013 года
# - Изменение продаж по платформам. В среднем новые платформы появляются раз в 8 лет. Сейчас актуальны `DS3`, `PS4`, `XOne`.
# - Собрали данные для анализа с 2013 года с платформами `XOne` и `PS4` в один датафрейм;
# - Продажи игр в разбивке по платформам и определились, что `PS4`сейчас самая прибыльная и перспективная платформа.
# - Влияние отзывов критиков и пользователей на продажи. Отзывы пользователей не влияют на продажи. Для хороших продаж нужны отзывы критиков от 70 баллов.
# - Подробно продажи игр по жанрам. Самый популярный жанр `Shooter`, второе и третье место делят три жанра  `Racing`, `Action`, `Sports`.
#
# Собрали портреты пользователей.
# В Японии пользователи больше предпочитают игры с меньшим насилием, чем в остальном мире. Так же там популярны портативные игровые консоли. Рынок видео игр мал в сравнении с Северной Америкой и Европой и очень специфичен.
#
# Северная Америка и Европа схожи по предпочтениям, кроме того, что в Северной Америке после `PS4` предпочитают платфомы `XOne` и `X360`, в то время как в Европе `PS3` и `XOne`.
#
# В оценке портретов пользоватлей стало ясно, что весь мир предпочитает игры с насилием: рейтинг `M` - Mature. `PS4` и `XOne` укрепили свои позиции лидеров рынка и самых перспективных платформ.
#
# Проверили гипотезы:
# - Средние пользовательские рейтинги платформ Xbox One и PC одинаковые. Ответ: Это верное утверждение.
# - Средние пользовательские рейтинги жанров Action и Sports разные. Ответ: Это верное утверждение.
#
# Общий вывод:
# Для успеха видеоигры нужно захватить аудиторию с платформ `PS4` и `XOne`. Создавать игру в жанре `Shooter` с рейтингом по ESRB `M`. Продажи можно нацелить На Северную Америку и Европу. Сделать все, что бы получить оценку критиков выше 70 баллов.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Выводы понятны и логичны, а самое главное подкреплены выявленными фактами.
#
# Ты очень серьезно подходишь к визуализации.
#
# Вот пара ссылок на полезные источники:https://habr.com/ru/company/otus/blog/540526/, https://pythonru.com/biblioteki/seaborn-plot
# </div>

# %% [markdown]
# <div style="border:solid indigo 3px; padding: 20px">
# <div class="alert alert-success">
# <b>Обратная связь v.1</b>
#
# 👋
# Андрей, замечательная работа, ты мыслишь нестандартно, это отличный навык, который у тебя уже есть, ты последователен и вдумчив. Твою работу очень интересно читать и проверять.  Я оставил несколько обязательных поправок для тебя и после этого буду готов сразу принять проект.
#
# Удачи в доработках, жду!

# %% [markdown]
# <div style="border:solid indigo 3px; padding: 20px">
# <div class="alert alert-info">
# <b>Обратная связь студента v.1</b>
#
# Василий, спасибо за поддержку! Вроде учел все недочеты и поправил их.
# </div>

# %% [markdown]
# <div style="border:solid indigo 3px; padding: 20px">
# <div class="alert alert-success">
# <b>Обратная связь v.2</b>
#
# 👋
#
# Андрей, спасибо тебе за исправления критических моментов, а также спасибо за хорошую работу.
#
# Поздравляю с успешным завершением проекта 🥳 🎉
#
# И желаю успехов в новых работах 😊
